# %%
from matplotlib import pyplot as plt
import numpy as np

def gauss(x, mu, sigma):
    g = 1./(sigma*np.sqrt(2.*np.pi))
    arg = (-1/2)*((x-mu)/sigma)**2
    return g*np.exp(arg)

xx = []      # ordinates
g  = []      # abscissa
m  = -5      # mean offset
s  = 3.2     # standard deviation sigma

x0, x1, dx = -20, 20, .01      # x-axis range and increment

for x in np.arange(x0, x1, dx):
    g.append(gauss(x, m, s))
    xx.append(x)
plt.plot(xx, g)

# %%
from random import randint


def coin(): return float(randint(0,1))

def sample_mean(n):
    sample_sum = 0.
    for i in range(n): sample_sum += coin()
    return sample_sum/n

h = np.zeros(101)                        # histogram
n_samples = 10000
tosses = 30
for i in range(n_samples):
    h[int(sample_mean(tosses)*100)] += 1
    
plt.plot(h)

# %%
h
# Out:
# array([0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 8.000e+00, 0.000e+00, 0.000e+00, 1.500e+01,
#        0.000e+00, 0.000e+00, 5.100e+01, 0.000e+00, 0.000e+00, 0.000e+00,
#        1.390e+02, 0.000e+00, 0.000e+00, 2.890e+02, 0.000e+00, 0.000e+00,
#        4.930e+02, 0.000e+00, 0.000e+00, 0.000e+00, 8.080e+02, 0.000e+00,
#        0.000e+00, 1.148e+03, 0.000e+00, 0.000e+00, 1.320e+03, 0.000e+00,
#        0.000e+00, 0.000e+00, 1.511e+03, 0.000e+00, 0.000e+00, 1.358e+03,
#        0.000e+00, 0.000e+00, 1.104e+03, 0.000e+00, 0.000e+00, 0.000e+00,
#        7.460e+02, 0.000e+00, 0.000e+00, 5.020e+02, 0.000e+00, 0.000e+00,
#        2.900e+02, 0.000e+00, 0.000e+00, 0.000e+00, 1.260e+02, 0.000e+00,
#        0.000e+00, 6.000e+01, 0.000e+00, 0.000e+00, 2.700e+01, 0.000e+00,
# ...
